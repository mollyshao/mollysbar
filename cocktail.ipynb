# %%
import pandas as pd
import numpy as np
df = pd.read_csv("all_drinks.csv")

# %%
df
# Out:
#      Unnamed: 0                              strDrink         dateModified  \
# 0             0  '57 Chevy with a White License Plate  2016-07-18 22:49:04
# 1             1                        1-900-FUK-MEUP  2016-07-18 22:27:04
# 2             2                      110 in the shade  2016-02-03 14:51:57
# 3             3                151 Florida Bushwacker  2016-07-18 22:28:43
# 4             4                           155 Belmont  2016-10-05 12:36:28
# ..          ...                                   ...                  ...
# 541         541                       Zippy's Revenge  2017-01-28 16:18:33
# 542         542                        Zizi Coin-coin  2017-01-28 16:25:52
# 543         543                                Zoksel  2017-01-28 16:28:50
# 544         544                             Zorbatini  2017-01-28 16:32:35
# 545         545                                 Zorro  2017-01-28 16:34:43
#
#      idDrink strAlcoholic           strCategory  \
# 0      14029    Alcoholic              Cocktail
# 1      15395    Alcoholic                  Shot
# 2      15423    Alcoholic                  Beer
# 3      14588    Alcoholic  Milk / Float / Shake
# 4      15346    Alcoholic              Cocktail
# ..       ...          ...                   ...
# 541    14065    Alcoholic              Cocktail
# 542    14594    Alcoholic   Punch / Party Drink
# 543    15691    Alcoholic     Soft Drink / Soda
# 544    16963    Alcoholic              Cocktail
# 545    15328    Alcoholic          Coffee / Tea
#
#                                          strDrinkThumb  \
# 0    http://www.thecocktaildb.com/images/media/drin...
# 1    http://www.thecocktaildb.com/images/media/drin...
# 2    http://www.thecocktaildb.com/images/media/drin...
# 3    http://www.thecocktaildb.com/images/media/drin...
# 4    http://www.thecocktaildb.com/images/media/drin...
# ..                                                 ...
# 541  http://www.thecocktaildb.com/images/media/drin...
# 542  http://www.thecocktaildb.com/images/media/drin...
# 543  http://www.thecocktaildb.com/images/media/drin...
# 544  http://www.thecocktaildb.com/images/media/drin...
# 545  http://www.thecocktaildb.com/images/media/drin...
#
#                      strGlass strIBA  strIngredient1  ... strMeasure15  \
# 0              Highball glass    NaN  Creme de Cacao  ...          NaN
# 1         Old-fashioned glass    NaN  Absolut Kurant  ...          NaN
# 2                  Beer Glass    NaN           Lager  ...          NaN
# 3                    Beer mug    NaN      Malibu rum  ...          NaN
# 4            White wine glass    NaN        Dark rum  ...          NaN
# ..                        ...    ...             ...  ...          ...
# 541       Old-fashioned glass    NaN        Amaretto  ...          NaN
# 542  Margarita/Coupette glass    NaN       Cointreau  ...          NaN
# 543              Beer pilsner    NaN            Beer  ...          NaN
# 544            Cocktail glass    NaN           Vodka  ...          NaN
# 545                Coffee Mug    NaN         Sambuca  ...          NaN
#
#     strMeasure2      strMeasure3  strMeasure4  strMeasure5  strMeasure6  \
# 0         1 oz
# 1       1/4 oz           1/4 oz       1/4 oz       1/4 oz       1/4 oz
# 2       1.5 oz
# 3       1/2 oz   1/2 oz Bacardi         1 oz         1 oz         3 oz
# 4      2 shots           1 shot       1 shot
# ..          ...              ...          ...          ...          ...
# 541       2 oz       4 oz Grape
# 542       2 cl           cubes\n    or lime\n           \n           \n
# 543          \n               \n      slice\n           \n           \n
# 544     1/4 oz
# 545       2 cl             2 cl
#
#     strMeasure7 strMeasure8 strMeasure9 strVideo
# 0                       NaN         NaN      NaN
# 1       1/2 oz      1/4 oz                   NaN
# 2                       NaN         NaN      NaN
# 3         1 oz       1 cup                   NaN
# 4                                            NaN
# ..          ...         ...         ...      ...
# 541                                 NaN      NaN
# 542          \n          \n          \n      NaN
# 543          \n          \n          \n      NaN
# 544                     NaN         NaN      NaN
# 545                                 NaN      NaN
#
# [546 rows x 41 columns]

# %%
df1 = df.replace(np.nan, '', regex=True)

# %%
df1=df1.replace("\\r\\n", "")

# %%
cols = ['strIngredient1','strIngredient10','strIngredient11','strIngredient12','strIngredient13','strIngredient14','strIngredient15','strIngredient2','strIngredient3','strIngredient4','strIngredient5','strIngredient6','strIngredient7','strIngredient8','strIngredient9']
df1['combined'] = df1[cols].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
import re

def clean_combined(combined):
    return re.sub("[^a-zA-Z0-9 ]", "", combined)

# %%
df1["clean_combined"] = df1["combined"].apply(clean_combined)

# %%
df1
# Out:
#      Unnamed: 0                              strDrink         dateModified  \
# 0             0  '57 Chevy with a White License Plate  2016-07-18 22:49:04
# 1             1                        1-900-FUK-MEUP  2016-07-18 22:27:04
# 2             2                      110 in the shade  2016-02-03 14:51:57
# 3             3                151 Florida Bushwacker  2016-07-18 22:28:43
# 4             4                           155 Belmont  2016-10-05 12:36:28
# ..          ...                                   ...                  ...
# 541         541                       Zippy's Revenge  2017-01-28 16:18:33
# 542         542                        Zizi Coin-coin  2017-01-28 16:25:52
# 543         543                                Zoksel  2017-01-28 16:28:50
# 544         544                             Zorbatini  2017-01-28 16:32:35
# 545         545                                 Zorro  2017-01-28 16:34:43
#
#      idDrink strAlcoholic           strCategory  \
# 0      14029    Alcoholic              Cocktail
# 1      15395    Alcoholic                  Shot
# 2      15423    Alcoholic                  Beer
# 3      14588    Alcoholic  Milk / Float / Shake
# 4      15346    Alcoholic              Cocktail
# ..       ...          ...                   ...
# 541    14065    Alcoholic              Cocktail
# 542    14594    Alcoholic   Punch / Party Drink
# 543    15691    Alcoholic     Soft Drink / Soda
# 544    16963    Alcoholic              Cocktail
# 545    15328    Alcoholic          Coffee / Tea
#
#                                          strDrinkThumb  \
# 0    http://www.thecocktaildb.com/images/media/drin...
# 1    http://www.thecocktaildb.com/images/media/drin...
# 2    http://www.thecocktaildb.com/images/media/drin...
# 3    http://www.thecocktaildb.com/images/media/drin...
# 4    http://www.thecocktaildb.com/images/media/drin...
# ..                                                 ...
# 541  http://www.thecocktaildb.com/images/media/drin...
# 542  http://www.thecocktaildb.com/images/media/drin...
# 543  http://www.thecocktaildb.com/images/media/drin...
# 544  http://www.thecocktaildb.com/images/media/drin...
# 545  http://www.thecocktaildb.com/images/media/drin...
#
#                      strGlass strIBA  strIngredient1  ...      strMeasure3  \
# 0              Highball glass         Creme de Cacao  ...
# 1         Old-fashioned glass         Absolut Kurant  ...          1/4 oz
# 2                  Beer Glass                  Lager  ...
# 3                    Beer mug             Malibu rum  ...  1/2 oz Bacardi
# 4            White wine glass               Dark rum  ...          1 shot
# ..                        ...    ...             ...  ...              ...
# 541       Old-fashioned glass               Amaretto  ...      4 oz Grape
# 542  Margarita/Coupette glass              Cointreau  ...          cubes\n
# 543              Beer pilsner                   Beer  ...               \n
# 544            Cocktail glass                  Vodka  ...
# 545                Coffee Mug                Sambuca  ...            2 cl
#
#     strMeasure4 strMeasure5 strMeasure6 strMeasure7 strMeasure8 strMeasure9  \
# 0
# 1       1/4 oz      1/4 oz      1/4 oz      1/2 oz      1/4 oz
# 2
# 3         1 oz        1 oz        3 oz        1 oz       1 cup
# 4       1 shot
# ..          ...         ...         ...         ...         ...         ...
# 541
# 542   or lime\n          \n          \n          \n          \n          \n
# 543     slice\n          \n          \n          \n          \n          \n
# 544
# 545
#
#     strVideo                                           combined  \
# 0                             Creme de Cacao       Vodka
# 1             Absolut Kurant       Grand Marnier Chambord ra...
# 2                                    Lager       Tequila
# 3             Malibu rum       Light rum 151 proof rum Dark ...
# 4              Dark rum       Light rum Vodka Orange juice
# ..       ...                                                ...
# 541                           Amaretto       Rum Kool-Aid
# 542                  Cointreau       Lemon juice Ice Lemon
# 543           Beer       Root beer Lemonade Coca-Cola 7-Up C...
# 544                                     Vodka       Ouzo
# 545           Sambuca       Bailey's irish cream White Creme...
#
#                                         clean_combined
# 0                    Creme de Cacao       Vodka
# 1    Absolut Kurant       Grand Marnier Chambord ra...
# 2                           Lager       Tequila
# 3    Malibu rum       Light rum 151 proof rum Dark ...
# 4     Dark rum       Light rum Vodka Orange juice
# ..                                                 ...
# 541                   Amaretto       Rum KoolAid
# 542         Cointreau       Lemon juice Ice Lemon
# 543  Beer       Root beer Lemonade CocaCola 7Up Cre...
# 544                            Vodka       Ouzo
# 545  Sambuca       Baileys irish cream White Creme ...
#
# [546 rows x 43 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf = vectorizer.fit_transform(df1["clean_combined"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def search(combined):
    #combined = "Creme de Cacao Vodka"
    name = df1.strDrink
    combined = clean_combined(combined)
    query_vec = vectorizer.transform([combined])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity,-5)[-5:]
    results = df1.iloc[indices][::-1]
    return results

# %%
results
# Out:
#      Unnamed: 0                              strDrink         dateModified  \
# 243         243                             Foxy Lady  2017-09-04 11:10:44
# 71           71                            Almond Joy  2017-01-02 20:18:16
# 282         282                           Grasshopper  2017-09-02 17:26:53
# 411         411                        Poppy Cocktail  2017-09-02 23:05:15
# 0             0  '57 Chevy with a White License Plate  2016-07-18 22:49:04
#
#      idDrink strAlcoholic     strCategory  \
# 243    11375    Alcoholic  Ordinary Drink
# 71     11024    Alcoholic  Ordinary Drink
# 282    17200    Alcoholic  Ordinary Drink
# 411    11959    Alcoholic  Ordinary Drink
# 0      14029    Alcoholic        Cocktail
#
#                                          strDrinkThumb        strGlass  \
# 243  http://www.thecocktaildb.com/images/media/drin...  Cocktail glass
# 71   http://www.thecocktaildb.com/images/media/drin...  Cocktail glass
# 282  http://www.thecocktaildb.com/images/media/drin...  Cocktail glass
# 411  http://www.thecocktaildb.com/images/media/drin...  Cocktail glass
# 0    http://www.thecocktaildb.com/images/media/drin...  Highball glass
#
#                     strIBA         strIngredient1  ... strMeasure3  \
# 243                                      Amaretto  ...       2 oz
# 71                                       Amaretto  ...       2 oz
# 282  Contemporary Classics  Green Creme de Menthe  ...     3/4 oz
# 411                                           Gin  ...
# 0                                  Creme de Cacao  ...
#
#     strMeasure4 strMeasure5 strMeasure6 strMeasure7 strMeasure8 strMeasure9  \
# 243
# 71
# 282
# 411
# 0
#
#     strVideo                                           combined  \
# 243             Amaretto       Creme de Cacao Light cream
# 71              Amaretto       Creme de Cacao Light cream
# 282           Green Creme de Menthe       Creme de Cacao Lig...
# 411                             Gin       Creme de Cacao
# 0                             Creme de Cacao       Vodka
#
#                                         clean_combined
# 243    Amaretto       Creme de Cacao Light cream
# 71     Amaretto       Creme de Cacao Light cream
# 282  Green Creme de Menthe       Creme de Cacao Lig...
# 411                    Gin       Creme de Cacao
# 0                    Creme de Cacao       Vodka
#
# [5 rows x 43 columns]

# %%
import ipywidgets as widgets
from IPython.display import display

df1_input = widgets.Text(
    value = "Vodka",
    description = "Ingredients:",
    disabled=False
)

cocktail_list = widgets.Output()

def on_type(data):
    with cocktail_list:
        cocktail_list.clear_output()
        combined = data["new"]
        if len(combined) > 1:
            display(search(combined))

df1_input.observe(on_type, names='value')

display(df1_input, cocktail_list)
# Out:
# Text(value='Vodka', description='Ingredients:')
# Output()
